# %%
import pandas as pd
import re
from tqdm.auto import tqdm
tqdm.pandas()

'''set path'''
import glob, os, sys; sys.path.append('../src')

# %%
data = pd.read_csv("../data/undp_jobs_processed.csv", index_col=0)
# Out:
# /var/folders/cz/gwq3cszn2wg2d6wfc251ntp80000gn/T/ipykernel_57254/1283932188.py:1: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("../data/undp_jobs_processed.csv", index_col=0)

# %%
data
# Out:
#                                                      text  \
# 0       {'content': ['hiv and sti clinical consultant ...
# 1       {'content': ['internship- pacific digital econ...
# 2       {'content': ['consultant international spécial...
# 3       {'content': ['consultant national pour l’élabo...
# 4       {'content': ['individual consultant - national...
# ...                                                   ...
# 104995  {'content': ['administrative associate', 'loca...
# 104996  {'content': ['learning assistant, leadership d...
# 104997  {'content': ['consultant: preparation of a un ...
# 104998                                    {'content': []}
# 104999  {'content': ['deputy head of resident coordina...
#
#                                                     title  \
# 0                      hiv and sti clinical consultant ic
# 1       internship pacific digital economy programme p...
# 2       consultant international spécialisé dans le co...
# ...
